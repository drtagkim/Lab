# %% [markdown]
# <a href="https://colab.research.google.com/github/drtagkim/Lab/blob/master/%EB%B6%84%EC%84%9D_TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 제목 1
# 가ㅏㅇ러아ㅓ아한함넝라***ㅓㅏ너마ㅣㅓ아ㅣ허마ㅣ넣***나 ㅏㅣㄴ허ㅏㄴ어하ㅣ머니아허ㅏ니머아ㅣ헌이ㅏ험니ㅏ허나ㅣ어
#
#
#
# ```r
# install.packages("irr")
# library(irr)
# ```
#
# - dd
# - dd
# - dd
#
# 1. dd
# 1. dd
# 1. dd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
install.packages("irr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘lpSolve’

# %%
library(irr)
# Out:
# Loading required package: lpSolve
