# %% [markdown]
# https://pygam.readthedocs.io/en/latest/notebooks/tour_of_pygam.html

# %%
# !pip install pygam
# Out:
# Collecting pygam
#   Downloading pygam-0.8.0-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/tagg/opt/anaconda3/lib/python3.8/site-packages (from pygam) (1.19.2)
# Requirement already satisfied: scipy in /Users/tagg/opt/anaconda3/lib/python3.8/site-packages (from pygam) (1.5.2)
# Requirement already satisfied: future in /Users/tagg/opt/anaconda3/lib/python3.8/site-packages (from pygam) (0.18.2)
# Collecting progressbar2
#   Downloading progressbar2-3.53.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: six in /Users/tagg/opt/anaconda3/lib/python3.8/site-packages (from progressbar2->pygam) (1.15.0)
# Collecting python-utils>=2.3.0
#   Downloading python_utils-2.5.6-py2.py3-none-any.whl (12 kB)
# Installing collected packages: python-utils, progressbar2, pygam
# Successfully installed progressbar2-3.53.1 pygam-0.8.0 python-utils-2.5.6
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/tagg/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
from pygam import PoissonGAM, s, te
from pygam.datasets import chicago

X, y = chicago(return_X_y=True)

gam = PoissonGAM(s(0, n_splines=200) + te(3, 1) + s(2)).fit(X, y)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

plt.ion()
plt.rcParams['figure.figsize'] = (12, 8)

# %%
XX = gam.generate_X_grid(term=1, meshgrid=True)
Z = gam.partial_dependence(term=1, X=XX, meshgrid=True)

ax = plt.axes(projection='3d')
ax.plot_surface(XX[0], XX[1], Z, cmap='viridis')

# %%
from pygam import LinearGAM, s, f
from pygam.datasets import wage

X, y = wage(return_X_y=True)

## model
gam = LinearGAM(s(0) + s(1) + f(2))
gam.gridsearch(X, y)


## plotting
plt.figure();
fig, axs = plt.subplots(1,3);

titles = ['year', 'age', 'education']
for i, ax in enumerate(axs):
    XX = gam.generate_X_grid(term=i)
    ax.plot(XX[:, i], gam.partial_dependence(term=i, X=XX))
    ax.plot(XX[:, i], gam.partial_dependence(term=i, X=XX, width=.95)[1], c='r', ls='--')
    if i == 0:
        ax.set_ylim(-30,30)
    ax.set_title(titles[i]);
